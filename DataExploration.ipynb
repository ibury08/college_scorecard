# %%
import pandas as pd
import csv
import os

# %%
data_dict = pd.read_csv('/Users/ianbury/Springboard/collegeScorecard/CollegeScorecardDataDictionary.csv')
data = {}
directory = os.fsencode('/Users/ianbury/Springboard/collegeScorecard/CollegeScorecard_Raw_Data/')

for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith('.csv'):
        
        data[filename[7:12]] = pd.read_csv('/Users/ianbury/Springboard/collegeScorecard/CollegeScorecard_Raw_Data/'+filename)
# Out:
# /Users/ianbury/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/ianbury/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (1,6,442,451,598,607,611,620,624,633,789,802,806,815,893,906,971,984,997,1153,1166,1407,1408,1411,1424,1425,1426,1431,1432,1433,1437,1438,1439,1440,1445,1446,1447,1451,1452,1453,1454,1459,1460,1461,1465,1466,1467,1468,1473,1474,1475,1479,1480,1481,1482,1487,1488,1489,1501,1502,1537,1538,1539,1540,1541,1542,1606,1609,1610,1611,1613,1614,1615,1616,1688,1689,1690,1691,1692) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...

# %%
data_dict
# Out:
#                                    NAME OF DATA ELEMENT dev-category  \
# 0                               Unit ID for institution         root
# 1                        8-digit OPE ID for institution         root
# 2                        6-digit OPE ID for institution         root
# 3                                      Institution name       school
# 4                                                  City       school
# 5                                        State postcode       school
# 6                                              ZIP code       school
# 7                            Accreditor for institution       school
# 8                        URL for institution's homepage       school
# 9            URL for institution's net price calculator       school
# 10       Predominant degree awarded (recoded 0s and 4s)       school
# 11    Schools that are on Heightened Cash Monitoring...       school
# 12                                 Flag for main campus       school
# ...
